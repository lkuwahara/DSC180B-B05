# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics
import xgboost as xgb
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
trips = pd.read_csv("trips.csv")
trips
# Out:
#           activityid  personid        modechoice
# 0                  1         3              WALK
# 1                  2         3              WALK
# 2                  3         3              WALK
# 3                  4         3              WALK
# 4                  5         3              WALK
# ...              ...       ...               ...
# 14047024    17147588   4113994  DRIVE_ALONE_FREE
# 14047025    17147589   4113994  DRIVE_ALONE_FREE
# 14047026    17147590   4113994  DRIVE_ALONE_FREE
# 14047027    17147592   4113995      SHARED_3_HOV
# 14047028    17147593   4113995  DRIVE_ALONE_FREE
#
# [14047029 rows x 3 columns]

# %%
trips.isnull().sum()
# Out:
# activityid    0
# personid      0
# modechoice    0
# dtype: int64

# %%
trips['modechoice'].value_counts()
# Out:
# DRIVE_ALONE_FREE    6156506
# SHARED_2_HOV        3507285
# SHARED_3_HOV        2814408
# WALK                1022834
# WALK_SET             214366
# SCH_BUS              194123
# BIKE                  69645
# SHARED_3_PAY          17088
# SHARED_2_PAY          15450
# KNR_SET               13633
# PNR_SET               11926
# DRIVE_ALONE_PAY        9765
# Name: modechoice, dtype: int64

# %%
utilityvars = pd.read_csv("utilityvars.csv")
utilityvars
# Out:
#           activityid  age  gender  autosuf  numhouseholdpersons  income  \
# 0           12150818    4    True        2                    2       4
# 1            3018709    6   False        2                    2       1
# 2            8809200    6   False        2                    6       3
# 3           11332534    4   False        2                    1       2
# 4            6130767    6   False        2                    3       2
# ...              ...  ...     ...      ...                  ...     ...
# 14047024    10138525    2    True        2                    4       2
# 14047025    16270294    7   False        2                    4       3
# 14047026    16270295    7   False        2                    4       3
# 14047027    10138526    2    True        2                    4       2
# 14047028    10138527    2    True        2                    4       2
#
#              oduden     oempden  ototint     dempden  sovdrivetime  \
# 0          9.633200   11.594058      4.0   67.659134      5.053318
# 1          8.304700   70.117912     12.0   32.273338     31.226185
# 2         10.189500   47.538746      3.0   13.567157     30.145569
# 3         13.393200   21.983759      4.0   51.544109     24.318232
# 4         13.274000    6.568953      3.0    8.480003     25.267041
# ...             ...         ...      ...         ...           ...
# 14047024  35.460899  286.328949     14.0   12.385718     56.546418
# 14047025  17.207199   19.868286     13.0    1.423494      1.403090
# 14047026  16.574200    1.423494     13.0   88.151642     12.287907
# 14047027  22.916100   12.385718     14.0    8.472905      1.173692
# 14047028  23.146999    8.472905     14.0  950.602234     27.118087
#
#           hovdrivetime  tolldrivetime  tollcostsov  tollcosthov2  \
# 0             5.053318       5.053318          0.0           0.0
# 1            31.226185      31.226185          0.0           0.0
# 2            30.145569      30.145569          0.0           0.0
# 3            24.318232      24.318232          0.0           0.0
# 4            25.267041      25.267041          0.0           0.0
# ...                ...            ...          ...           ...
# 14047024     56.546418      56.546418          0.0           0.0
# 14047025      1.403090       1.403090          0.0           0.0
# 14047026     12.287907      12.287907          0.0           0.0
# 14047027      1.173692       1.173692          0.0           0.0
# 14047028     27.118087      27.118087          0.0           0.0
#
#           tollcosthov3   walkttime  walktotransitutility  \
# 0                  0.0   10.677524                -999.0
# 1                  0.0  113.844883                -999.0
# 2                  0.0  106.238420                -999.0
# 3                  0.0   78.687684                -999.0
# 4                  0.0   71.307144                -999.0
# ...                ...         ...                   ...
# 14047024           0.0  193.717741                -999.0
# 14047025           0.0    3.069109                -999.0
# 14047026           0.0   31.580930                -999.0
# 14047027           0.0    1.252347                -999.0
# 14047028           0.0   65.794873                -999.0
#
#           drivetotransitutility  parkingcost  parkingwalktime     sovcost  \
# 0                        -999.0          0.0              0.0   46.447229
# 1                        -999.0          0.0              0.0  495.225231
# 2                        -999.0          0.0              0.0  462.137117
# 3                        -999.0          0.0              0.0  342.291418
# 4                        -999.0          0.0              0.0  310.186071
# ...                         ...          ...              ...         ...
# 14047024                 -999.0          0.0              0.0  842.672156
# 14047025                 -999.0          0.0              0.0   13.350623
# 14047026                 -999.0          0.0              0.0  137.377041
# 14047027                 -999.0          0.0              0.0    5.447711
# 14047028                 -999.0          0.0              0.0  286.207691
#
#              hovcost    tollcost  tourpurpose  tourmode  firststop  laststop  \
# 0          46.447229   46.447229            0         5       True     False
# 1         495.225231  495.225231            0         1      False     False
# 2         462.137117  462.137117            0         1      False     False
# 3         342.291418  342.291418            0         1      False     False
# 4         310.186071  310.186071            0         1      False     False
# ...              ...         ...          ...       ...        ...       ...
# 14047024  842.672156  842.672156            5         5      False     False
# 14047025   13.350623   13.350623            5         3      False     False
# 14047026  137.377041  137.377041            5         3      False     False
# 14047027    5.447711    5.447711            5         5      False     False
# 14047028  286.207691  286.207691            5         5      False      True
#
#           zerototalstops  targettripmode
# 0                  False               1
# 1                  False               1
# 2                   True               1
# 3                  False               1
# 4                  False               1
# ...                  ...             ...
# 14047024           False               5
# 14047025           False               3
# 14047026           False               3
# 14047027           False               3
# 14047028           False               5
#
# [14047029 rows x 30 columns]

# %%
# is there any missingness?
utilityvars.isnull().sum()
# Out:
# activityid               0
# age                      0
# gender                   0
# autosuf                  0
# numhouseholdpersons      0
# income                   0
# oduden                   0
# oempden                  0
# ototint                  0
# dempden                  0
# sovdrivetime             0
# hovdrivetime             0
# tolldrivetime            0
# tollcostsov              0
# tollcosthov2             0
# tollcosthov3             0
# walkttime                0
# walktotransitutility     0
# drivetotransitutility    0
# parkingcost              0
# parkingwalktime          0
# sovcost                  0
# hovcost                  0
# tollcost                 0
# tourpurpose              0
# tourmode                 0
# firststop                0
# laststop                 0
# zerototalstops           0
# targettripmode           0
# dtype: int64

# %%
props = utilityvars['targettripmode'].value_counts()/14047029
props
# Out:
# 1     0.438187
# 3     0.250810
# 5     0.201549
# 7     0.071458
# 9     0.015199
# 12    0.009771
# 8     0.007629
# 11    0.001731
# 2     0.001459
# 6     0.000806
# 10    0.000717
# 4     0.000683
# Name: targettripmode, dtype: float64

# %%
# sample the whole dataset

# mode1 = utilityvars[utilityvars['targettripmode']==1].sample(n=1000, weights='walkttime', random_state=1)
# mode2 = utilityvars[utilityvars['targettripmode']==2].sample(n=1000, weights='walkttime', random_state=1)
# mode3 = utilityvars[utilityvars['targettripmode']==3].sample(n=1000, weights='walkttime', random_state=1)
# mode4 = utilityvars[utilityvars['targettripmode']==4].sample(n=1000, weights='walkttime', random_state=1)
# mode5 = utilityvars[utilityvars['targettripmode']==5].sample(n=1000, weights='walkttime', random_state=1)
# mode6 = utilityvars[utilityvars['targettripmode']==6].sample(n=1000, weights='walkttime', random_state=1)
# mode7 = utilityvars[utilityvars['targettripmode']==7].sample(n=1000, weights='walkttime', random_state=1)
# mode8 = utilityvars[utilityvars['targettripmode']==8].sample(n=1000, weights='walkttime', random_state=1)
# mode9 = utilityvars[utilityvars['targettripmode']==9].sample(n=1000, weights='walkttime', random_state=1)
# mode10 = utilityvars[utilityvars['targettripmode']==10].sample(n=1000, weights='walkttime', random_state=1)
# mode11 = utilityvars[utilityvars['targettripmode']==11].sample(n=1000, weights='walkttime', random_state=1)
# mode12 = utilityvars[utilityvars['targettripmode']==12].sample(n=1000, weights='walkttime', random_state=1)

# %%
# combined_subsamples = pd.concat([mode1,mode2,mode3,mode4,mode5,mode6,mode7,mode8,mode9,mode10,mode11,mode12], axis=0)

# %%
subsample1 = utilityvars.sample(n=1000000, random_state=1)

# %%
subsample1['targettripmode'].value_counts()/1000000
# Out:
# 1     0.437538
# 3     0.250873
# 5     0.202280
# 7     0.071412
# 9     0.015142
# 12    0.009754
# 8     0.007588
# 11    0.001729
# 2     0.001481
# 6     0.000826
# 4     0.000692
# 10    0.000685
# Name: targettripmode, dtype: float64

# %%
size = 500000
mode1 = utilityvars[utilityvars['targettripmode']==1].sample(n=int(round(size*props[1])), random_state=1)
mode2 = utilityvars[utilityvars['targettripmode']==2].sample(n=int(round(size*props[2])), random_state=1)
mode3 = utilityvars[utilityvars['targettripmode']==3].sample(n=int(round(size*props[3])), random_state=1)
mode4 = utilityvars[utilityvars['targettripmode']==4].sample(n=int(round(size*props[4])), random_state=1)
mode5 = utilityvars[utilityvars['targettripmode']==5].sample(n=int(round(size*props[5])), random_state=1)
mode6 = utilityvars[utilityvars['targettripmode']==6].sample(n=int(round(size*props[6])), random_state=1)
mode7 = utilityvars[utilityvars['targettripmode']==7].sample(n=int(round(size*props[7])), random_state=1)
mode8 = utilityvars[utilityvars['targettripmode']==8].sample(n=int(round(size*props[8])), random_state=1)
mode9 = utilityvars[utilityvars['targettripmode']==9].sample(n=int(round(size*props[9])), random_state=1)
mode10 = utilityvars[utilityvars['targettripmode']==10].sample(n=int(round(size*props[10])), random_state=1)
mode11 = utilityvars[utilityvars['targettripmode']==11].sample(n=int(round(size*props[11])), random_state=1)
mode12 = utilityvars[utilityvars['targettripmode']==12].sample(n=int(round(size*props[12])), random_state=1)

# %%
subsample2 = pd.concat([mode1,mode2,mode3,mode4,mode5,mode6,mode7,mode8,mode9,mode10,mode11,mode12], axis=0)

# %%
# One-hot encode the categorical variables (the variables only include 0 and -1 don't need to be encoded)
new_utilityvars1 = pd.get_dummies(subsample1, columns=["tourpurpose"], prefix=["tourpurpose"])
new_utilityvars1
# Out:
#           activityid  age  gender  autosuf  numhouseholdpersons  income  \
# 1387296      1564459    6    True        2                    4       2
# 10382234     4077144    7   False        2                    1       1
# 13391127    13696540    4   False        2                    1       3
# 2068532     16094595    2   False        1                    5       3
# 10861969     7204173    7   False        2                    1       1
# ...              ...  ...     ...      ...                  ...     ...
# 1111184     10612140    1    True        1                    6       5
# 7450224     10761986    4    True        2                    2       2
# 4577494     13950333    6    True        1                    2       5
# 7882379      8566521    7   False        2                    1       3
# 10334192    10717909    4    True        1                    4       4
#
#            oduden     oempden  ototint     dempden  sovdrivetime  \
# 1387296    7.5717   36.388775      4.0   53.826412     16.346799
# 10382234  13.0945    5.733529      3.0  160.396484     13.076593
# 13391127   7.4989   12.729101     10.0   27.067551     13.678353
# 2068532    8.5809   96.584641      6.0   30.264742      5.973807
# 10861969   4.2448   11.421939      1.0   94.689743      5.519096
# ...           ...         ...      ...         ...           ...
# 1111184    4.2689  107.713318      2.0   24.240088     19.503379
# 7450224    0.5111   44.011829      1.0    2.223180      6.651095
# 4577494    8.2355   27.750124      3.0   32.060444      0.438984
# 7882379    0.8648   22.147526     26.0    5.116726     28.081127
# 10334192   1.2883    8.680181      1.0   47.049484      6.369174
#
#           hovdrivetime  tolldrivetime  tollcostsov  tollcosthov2  \
# 1387296      16.346799      16.346799          0.0           0.0
# 10382234     12.217715      13.076593          0.0           0.0
# 13391127     13.666029      13.678353          0.0           0.0
# 2068532       5.973807       5.973807          0.0           0.0
# 10861969      5.519096       5.519096          0.0           0.0
# ...                ...            ...          ...           ...
# 1111184      19.503379      19.503379          0.0           0.0
# 7450224       6.651095       6.651095          0.0           0.0
# 4577494       0.438984       0.438984          0.0           0.0
# 7882379      28.081127      28.081127          0.0           0.0
# 10334192      6.369174       6.369174          0.0           0.0
#
#           tollcosthov3  walkttime  walktotransitutility  \
# 1387296            0.0  42.808210                -999.0
# 10382234           0.0  34.379486                -999.0
# 13391127           0.0  48.839710                -999.0
# 2068532            0.0  17.714907                -999.0
# 10861969           0.0   9.530084                -999.0
# ...                ...        ...                   ...
# 1111184            0.0  52.896431                -999.0
# 7450224            0.0  14.117167                -999.0
# 4577494            0.0   1.168539                -999.0
# 7882379            0.0  95.469129                -999.0
# 10334192           0.0  10.908468                -999.0
#
#           drivetotransitutility  parkingcost  parkingwalktime     sovcost  \
# 1387296                  -999.0          0.0              0.0  186.215711
# 10382234                 -999.0          0.0              0.0  149.550759
# 13391127                 -999.0          0.0              0.0  212.452735
# 2068532                  -999.0          0.0              0.0   77.059845
# 10861969                 -999.0          0.0              0.0   41.455863
# ...                         ...          ...              ...         ...
# 1111184                  -999.0          0.0              0.0  230.099469
# 7450224                  -999.0          0.0              0.0   61.409677
# 4577494                  -999.0          0.0              0.0    5.083145
# 7882379                  -999.0          0.0              0.0  415.290702
# 10334192                 -999.0          0.0              0.0   47.451833
#
#              hovcost    tollcost  tourmode  firststop  laststop  \
# 1387296   186.215711  186.215711         1      False     False
# 10382234  144.172397  149.550759         1      False      True
# 13391127  212.667810  212.452735         1      False     False
# 2068532    77.059845   77.059845         3      False     False
# 10861969   41.455863   41.455863         1      False     False
# ...              ...         ...       ...        ...       ...
# 1111184   230.099469  230.099469         3       True     False
# 7450224    61.409677   61.409677         8      False     False
# 4577494     5.083145    5.083145         3      False     False
# 7882379   415.290702  415.290702         1      False     False
# 10334192   47.451833   47.451833         5      False     False
#
#           zerototalstops  targettripmode  tourpurpose_0  tourpurpose_1  \
# 1387296             True               1              0              0
# 10382234           False               1              0              0
# 13391127           False               1              0              0
# 2068532             True               3              0              0
# 10861969           False               1              1              0
# ...                  ...             ...            ...            ...
# 1111184            False               3              0              0
# 7450224            False               8              1              0
# 4577494            False               1              0              0
# 7882379             True               1              0              0
# 10334192           False               5              0              0
#
#           tourpurpose_2  tourpurpose_3  tourpurpose_4  tourpurpose_5  \
# 1387296               0              0              1              0
# 10382234              0              1              0              0
# 13391127              0              0              0              0
# 2068532               1              0              0              0
# 10861969              0              0              0              0
# ...                 ...            ...            ...            ...
# 1111184               1              0              0              0
# 7450224               0              0              0              0
# 4577494               0              0              0              1
# 7882379               0              0              0              1
# 10334192              0              0              0              1
#
#           tourpurpose_6  tourpurpose_7
# 1387296               0              0
# 10382234              0              0
# 13391127              1              0
# 2068532               0              0
# 10861969              0              0
# ...                 ...            ...
# 1111184               0              0
# 7450224               0              0
# 4577494               0              0
# 7882379               0              0
# 10334192              0              0
#
# [1000000 rows x 37 columns]

# %%
new_utilityvars2 = pd.get_dummies(subsample2, columns=["tourpurpose"], prefix=["tourpurpose"])
new_utilityvars2
# Out:
#           activityid  age  gender  autosuf  numhouseholdpersons  income  \
# 389395       6846232    6    True        2                    1       3
# 9670948      2110084    7    True        1                    4       4
# 12239774    10040064    6    True        2                    4       2
# 8333334      5200740    7   False        2                    2       3
# 5401543      3080529    7    True        1                    2       1
# ...              ...  ...     ...      ...                  ...     ...
# 7530275     12850414    1   False        1                    2       3
# 1315937      4343516    3    True        1                    4       4
# 1811575       931169    1    True        2                    3       3
# 1577591      4171930    2    True        2                    2       3
# 7217339     13029723    1    True        2                    9       3
#
#            oduden    oempden  ototint    dempden  sovdrivetime  hovdrivetime  \
# 389395     4.7632  27.730175     23.0  24.913393      5.347993      5.347993
# 9670948    9.2246  15.671348      6.0  31.653795      2.035063      2.035063
# 12239774  17.5495  41.898407     13.0   2.250410     14.014216     14.014216
# 8333334    6.9557  33.792797      1.0   3.054741     14.571569     14.571569
# 5401543   11.6963   5.626131      6.0   6.404369      6.707609      6.707609
# ...           ...        ...      ...        ...           ...           ...
# 7530275    6.3834  35.998531     10.0  21.200064      0.758012      0.758012
# 1315937   10.3973  21.256468      4.0  99.809555      7.535834      7.535834
# 1811575    1.9526  11.972782     26.0   7.575649      9.073135      9.073135
# 1577591   11.2013  30.438572      4.0  39.912827      6.276231      6.276231
# 7217339   15.8776  74.323288     13.0  29.077522      3.388680      3.388680
#
#           tolldrivetime  tollcostsov  tollcosthov2  tollcosthov3  walkttime  \
# 389395         5.347993          0.0           0.0           0.0   8.340726
# 9670948        2.035063          0.0           0.0           0.0   3.962483
# 12239774      14.014216          0.0           0.0           0.0  45.059798
# 8333334       14.571569          0.0           0.0           0.0  48.703855
# 5401543        6.707609          0.0           0.0           0.0  18.757141
# ...                 ...          ...           ...           ...        ...
# 7530275        0.758012          0.0           0.0           0.0   1.014384
# 1315937        7.535834          0.0           0.0           0.0  13.630794
# 1811575        9.073135          0.0           0.0           0.0  14.859670
# 1577591        6.276231          0.0           0.0           0.0  12.657595
# 7217339        3.388680          0.0           0.0           0.0   5.329330
#
#           walktotransitutility  drivetotransitutility  parkingcost  \
# 389395                  -999.0                 -999.0          0.0
# 9670948                 -999.0                 -999.0          0.0
# 12239774                -999.0                 -999.0          0.0
# 8333334                 -999.0                 -999.0          0.0
# 5401543                 -999.0                 -999.0          0.0
# ...                        ...                    ...          ...
# 7530275                 -999.0                 -999.0          0.0
# 1315937                 -999.0                 -999.0          0.0
# 1811575                 -999.0                 -999.0          0.0
# 1577591                 -999.0                 -999.0          0.0
# 7217339                 -999.0                 -999.0          0.0
#
#           parkingwalktime     sovcost     hovcost    tollcost  tourmode  \
# 389395                0.0   36.282156   36.282156   36.282156         1
# 9670948               0.0   17.236800   17.236800   17.236800         1
# 12239774              0.0  196.010116  196.010116  196.010116         1
# 8333334               0.0  211.861765  211.861765  211.861765         1
# 5401543               0.0   81.593560   81.593560   81.593560         1
# ...                   ...         ...         ...         ...       ...
# 7530275               0.0    4.412570    4.412570    4.412570        12
# 1315937               0.0   59.293954   59.293954   59.293954        12
# 1811575               0.0   64.639565   64.639565   64.639565        12
# 1577591               0.0   55.060536   55.060536   55.060536        12
# 7217339               0.0   23.182586   23.182586   23.182586        12
#
#           firststop  laststop  zerototalstops  targettripmode  tourpurpose_0  \
# 389395         True     False           False               1              0
# 9670948       False     False           False               1              0
# 12239774      False     False            True               1              0
# 8333334       False     False           False               1              1
# 5401543       False     False           False               1              0
# ...             ...       ...             ...             ...            ...
# 7530275       False     False            True              12              0
# 1315937       False     False            True              12              0
# 1811575       False     False            True              12              0
# 1577591       False     False            True              12              0
# 7217339       False     False            True              12              0
#
#           tourpurpose_1  tourpurpose_2  tourpurpose_3  tourpurpose_4  \
# 389395                0              0              0              1
# 9670948               0              0              0              0
# 12239774              0              0              0              1
# 8333334               0              0              0              0
# 5401543               0              0              0              0
# ...                 ...            ...            ...            ...
# 7530275               0              1              0              0
# 1315937               0              1              0              0
# 1811575               0              1              0              0
# 1577591               0              1              0              0
# 7217339               0              1              0              0
#
#           tourpurpose_5  tourpurpose_6  tourpurpose_7
# 389395                0              0              0
# 9670948               1              0              0
# 12239774              0              0              0
# 8333334               0              0              0
# 5401543               1              0              0
# ...                 ...            ...            ...
# 7530275               0              0              0
# 1315937               0              0              0
# 1811575               0              0              0
# 1577591               0              0              0
# 7217339               0              0              0
#
# [499999 rows x 37 columns]

# %%
# Build XGBoost tree model
new_utilityvars1 = pd.merge(new_utilityvars1.drop(['targettripmode', 'tourmode', 'activityid'], axis=1), new_utilityvars1[['targettripmode']], left_index=True, right_index=True, how="outer")
new_utilityvars1
# Out:
#           age  gender  autosuf  numhouseholdpersons  income   oduden  \
# 1387296     6    True        2                    4       2   7.5717
# 10382234    7   False        2                    1       1  13.0945
# 13391127    4   False        2                    1       3   7.4989
# 2068532     2   False        1                    5       3   8.5809
# 10861969    7   False        2                    1       1   4.2448
# ...       ...     ...      ...                  ...     ...      ...
# 1111184     1    True        1                    6       5   4.2689
# 7450224     4    True        2                    2       2   0.5111
# 4577494     6    True        1                    2       5   8.2355
# 7882379     7   False        2                    1       3   0.8648
# 10334192    4    True        1                    4       4   1.2883
#
#              oempden  ototint     dempden  sovdrivetime  hovdrivetime  \
# 1387296    36.388775      4.0   53.826412     16.346799     16.346799
# 10382234    5.733529      3.0  160.396484     13.076593     12.217715
# 13391127   12.729101     10.0   27.067551     13.678353     13.666029
# 2068532    96.584641      6.0   30.264742      5.973807      5.973807
# 10861969   11.421939      1.0   94.689743      5.519096      5.519096
# ...              ...      ...         ...           ...           ...
# 1111184   107.713318      2.0   24.240088     19.503379     19.503379
# 7450224    44.011829      1.0    2.223180      6.651095      6.651095
# 4577494    27.750124      3.0   32.060444      0.438984      0.438984
# 7882379    22.147526     26.0    5.116726     28.081127     28.081127
# 10334192    8.680181      1.0   47.049484      6.369174      6.369174
#
#           tolldrivetime  tollcostsov  tollcosthov2  tollcosthov3  walkttime  \
# 1387296       16.346799          0.0           0.0           0.0  42.808210
# 10382234      13.076593          0.0           0.0           0.0  34.379486
# 13391127      13.678353          0.0           0.0           0.0  48.839710
# 2068532        5.973807          0.0           0.0           0.0  17.714907
# 10861969       5.519096          0.0           0.0           0.0   9.530084
# ...                 ...          ...           ...           ...        ...
# 1111184       19.503379          0.0           0.0           0.0  52.896431
# 7450224        6.651095          0.0           0.0           0.0  14.117167
# 4577494        0.438984          0.0           0.0           0.0   1.168539
# 7882379       28.081127          0.0           0.0           0.0  95.469129
# 10334192       6.369174          0.0           0.0           0.0  10.908468
#
#           walktotransitutility  drivetotransitutility  parkingcost  \
# 1387296                 -999.0                 -999.0          0.0
# 10382234                -999.0                 -999.0          0.0
# 13391127                -999.0                 -999.0          0.0
# 2068532                 -999.0                 -999.0          0.0
# 10861969                -999.0                 -999.0          0.0
# ...                        ...                    ...          ...
# 1111184                 -999.0                 -999.0          0.0
# 7450224                 -999.0                 -999.0          0.0
# 4577494                 -999.0                 -999.0          0.0
# 7882379                 -999.0                 -999.0          0.0
# 10334192                -999.0                 -999.0          0.0
#
#           parkingwalktime     sovcost     hovcost    tollcost  firststop  \
# 1387296               0.0  186.215711  186.215711  186.215711      False
# 10382234              0.0  149.550759  144.172397  149.550759      False
# 13391127              0.0  212.452735  212.667810  212.452735      False
# 2068532               0.0   77.059845   77.059845   77.059845      False
# 10861969              0.0   41.455863   41.455863   41.455863      False
# ...                   ...         ...         ...         ...        ...
# 1111184               0.0  230.099469  230.099469  230.099469       True
# 7450224               0.0   61.409677   61.409677   61.409677      False
# 4577494               0.0    5.083145    5.083145    5.083145      False
# 7882379               0.0  415.290702  415.290702  415.290702      False
# 10334192              0.0   47.451833   47.451833   47.451833      False
#
#           laststop  zerototalstops  tourpurpose_0  tourpurpose_1  \
# 1387296      False            True              0              0
# 10382234      True           False              0              0
# 13391127     False           False              0              0
# 2068532      False            True              0              0
# 10861969     False           False              1              0
# ...            ...             ...            ...            ...
# 1111184      False           False              0              0
# 7450224      False           False              1              0
# 4577494      False           False              0              0
# 7882379      False            True              0              0
# 10334192     False           False              0              0
#
#           tourpurpose_2  tourpurpose_3  tourpurpose_4  tourpurpose_5  \
# 1387296               0              0              1              0
# 10382234              0              1              0              0
# 13391127              0              0              0              0
# 2068532               1              0              0              0
# 10861969              0              0              0              0
# ...                 ...            ...            ...            ...
# 1111184               1              0              0              0
# 7450224               0              0              0              0
# 4577494               0              0              0              1
# 7882379               0              0              0              1
# 10334192              0              0              0              1
#
#           tourpurpose_6  tourpurpose_7  targettripmode
# 1387296               0              0               1
# 10382234              0              0               1
# 13391127              1              0               1
# 2068532               0              0               3
# 10861969              0              0               1
# ...                 ...            ...             ...
# 1111184               0              0               3
# 7450224               0              0               8
# 4577494               0              0               1
# 7882379               0              0               1
# 10334192              0              0               5
#
# [1000000 rows x 35 columns]

# %%
df_array1 = new_utilityvars1.values
X1 = df_array1[:,0:34]
Y1 = df_array1[:,34]

# %%
seed = 7
test_size = 0.33
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, Y1, test_size=test_size, random_state=seed)

# %%
model1 = xgb.XGBClassifier()
model1.fit(X_train1, y_train1, eval_set = [(X_train1, y_train1), (X_test1, y_test1)], verbose = 0)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:08:41] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#               subsample=1, tree_method='exact', use_label_encoder=True,
#               validate_parameters=1, verbosity=None)

# %%
y_pred1 = [round(value) for value in model1.predict(X_test1)]
y_test1 = [round(value) for value in y_test1]

# %%
new_utilityvars2 = pd.merge(new_utilityvars2.drop(['targettripmode', 'tourmode', 'activityid'], axis=1), new_utilityvars2[['targettripmode']], left_index=True, right_index=True, how="outer")
new_utilityvars2
# Out:
#           age  gender  autosuf  numhouseholdpersons  income   oduden  \
# 389395      6    True        2                    1       3   4.7632
# 9670948     7    True        1                    4       4   9.2246
# 12239774    6    True        2                    4       2  17.5495
# 8333334     7   False        2                    2       3   6.9557
# 5401543     7    True        1                    2       1  11.6963
# ...       ...     ...      ...                  ...     ...      ...
# 7530275     1   False        1                    2       3   6.3834
# 1315937     3    True        1                    4       4  10.3973
# 1811575     1    True        2                    3       3   1.9526
# 1577591     2    True        2                    2       3  11.2013
# 7217339     1    True        2                    9       3  15.8776
#
#             oempden  ototint    dempden  sovdrivetime  hovdrivetime  \
# 389395    27.730175     23.0  24.913393      5.347993      5.347993
# 9670948   15.671348      6.0  31.653795      2.035063      2.035063
# 12239774  41.898407     13.0   2.250410     14.014216     14.014216
# 8333334   33.792797      1.0   3.054741     14.571569     14.571569
# 5401543    5.626131      6.0   6.404369      6.707609      6.707609
# ...             ...      ...        ...           ...           ...
# 7530275   35.998531     10.0  21.200064      0.758012      0.758012
# 1315937   21.256468      4.0  99.809555      7.535834      7.535834
# 1811575   11.972782     26.0   7.575649      9.073135      9.073135
# 1577591   30.438572      4.0  39.912827      6.276231      6.276231
# 7217339   74.323288     13.0  29.077522      3.388680      3.388680
#
#           tolldrivetime  tollcostsov  tollcosthov2  tollcosthov3  walkttime  \
# 389395         5.347993          0.0           0.0           0.0   8.340726
# 9670948        2.035063          0.0           0.0           0.0   3.962483
# 12239774      14.014216          0.0           0.0           0.0  45.059798
# 8333334       14.571569          0.0           0.0           0.0  48.703855
# 5401543        6.707609          0.0           0.0           0.0  18.757141
# ...                 ...          ...           ...           ...        ...
# 7530275        0.758012          0.0           0.0           0.0   1.014384
# 1315937        7.535834          0.0           0.0           0.0  13.630794
# 1811575        9.073135          0.0           0.0           0.0  14.859670
# 1577591        6.276231          0.0           0.0           0.0  12.657595
# 7217339        3.388680          0.0           0.0           0.0   5.329330
#
#           walktotransitutility  drivetotransitutility  parkingcost  \
# 389395                  -999.0                 -999.0          0.0
# 9670948                 -999.0                 -999.0          0.0
# 12239774                -999.0                 -999.0          0.0
# 8333334                 -999.0                 -999.0          0.0
# 5401543                 -999.0                 -999.0          0.0
# ...                        ...                    ...          ...
# 7530275                 -999.0                 -999.0          0.0
# 1315937                 -999.0                 -999.0          0.0
# 1811575                 -999.0                 -999.0          0.0
# 1577591                 -999.0                 -999.0          0.0
# 7217339                 -999.0                 -999.0          0.0
#
#           parkingwalktime     sovcost     hovcost    tollcost  firststop  \
# 389395                0.0   36.282156   36.282156   36.282156       True
# 9670948               0.0   17.236800   17.236800   17.236800      False
# 12239774              0.0  196.010116  196.010116  196.010116      False
# 8333334               0.0  211.861765  211.861765  211.861765      False
# 5401543               0.0   81.593560   81.593560   81.593560      False
# ...                   ...         ...         ...         ...        ...
# 7530275               0.0    4.412570    4.412570    4.412570      False
# 1315937               0.0   59.293954   59.293954   59.293954      False
# 1811575               0.0   64.639565   64.639565   64.639565      False
# 1577591               0.0   55.060536   55.060536   55.060536      False
# 7217339               0.0   23.182586   23.182586   23.182586      False
#
#           laststop  zerototalstops  tourpurpose_0  tourpurpose_1  \
# 389395       False           False              0              0
# 9670948      False           False              0              0
# 12239774     False            True              0              0
# 8333334      False           False              1              0
# 5401543      False           False              0              0
# ...            ...             ...            ...            ...
# 7530275      False            True              0              0
# 1315937      False            True              0              0
# 1811575      False            True              0              0
# 1577591      False            True              0              0
# 7217339      False            True              0              0
#
#           tourpurpose_2  tourpurpose_3  tourpurpose_4  tourpurpose_5  \
# 389395                0              0              1              0
# 9670948               0              0              0              1
# 12239774              0              0              1              0
# 8333334               0              0              0              0
# 5401543               0              0              0              1
# ...                 ...            ...            ...            ...
# 7530275               1              0              0              0
# 1315937               1              0              0              0
# 1811575               1              0              0              0
# 1577591               1              0              0              0
# 7217339               1              0              0              0
#
#           tourpurpose_6  tourpurpose_7  targettripmode
# 389395                0              0               1
# 9670948               0              0               1
# 12239774              0              0               1
# 8333334               0              0               1
# 5401543               0              0               1
# ...                 ...            ...             ...
# 7530275               0              0              12
# 1315937               0              0              12
# 1811575               0              0              12
# 1577591               0              0              12
# 7217339               0              0              12
#
# [499999 rows x 35 columns]

# %%
df_array2 = new_utilityvars2.values
X2 = df_array2[:,0:34]
Y2 = df_array2[:,34]

# %%
seed = 7
test_size = 0.33
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, Y2, test_size=test_size, random_state=seed)

# %%
model2 = xgb.XGBClassifier()
model2.fit(X_train2, y_train2, eval_set = [(X_train2, y_train2), (X_test2, y_test2)], verbose = 0)
# Out:
# [20:19:00] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#               subsample=1, tree_method='exact', use_label_encoder=True,
#               validate_parameters=1, verbosity=None)

# %%
y_pred2 = [round(value) for value in model2.predict(X_test2)]
y_test2 = [round(value) for value in y_test2]

# %%
# multilabel confusion matrix
metrics.multilabel_confusion_matrix(y_test1, y_pred1)
# Out:
# array([[[130323,  55280],
#         [ 20368, 124029]],
#
#        [[329311,    193],
#         [   290,    206]],
#
#        [[219220,  28146],
#         [ 55659,  26975]],
#
#        [[329724,     54],
#         [   206,     16]],
#
#        [[231673,  31559],
#         [ 27278,  39490]],
#
#        [[329621,    107],
#         [   225,     47]],
#
#        [[296680,   9598],
#         [ 13767,   9955]],
#
#        [[327145,    320],
#         [  2247,    288]],
#
#        [[324406,    633],
#         [  4538,    423]],
#
#        [[329760,      6],
#         [   234,      0]],
#
#        [[329431,     21],
#         [   545,      3]],
#
#        [[325300,   1489],
#         [  2049,   1162]]])

# %%
# accuracy
accuracy1 = metrics.accuracy_score(y_test1, y_pred1)
accuracy1
# Out:
# 0.6139212121212121

# %%
# sensitivity
sensitivity = metrics.recall_score(y_test1, y_pred1, average = 'macro')
sensitivity
# Out:
# 0.28524219562271896

# %%
# precision
precision = metrics.precision_score(y_test1, y_pred1, average = 'macro')
precision
# Out:
# 0.3944717028941404

# %%
# F1-score
f1 = (2 * precision * sensitivity) / (precision + sensitivity)
f1
# Out:
# 0.33108039982727105

# %%
accuracy2 = metrics.accuracy_score(y_test2, y_pred2)
accuracy2
# Out:
# 0.6111939393939394

# %%
# 13*13 confusion matrix
metrics.confusion_matrix(y_test1, y_pred1)
# Out:
# array([[124029,     89,  10367,      7,   6675,     15,   2825,    164,
#            184,      3,      5,     34],
#        [   253,    206,      9,     16,      4,      7,      1,      0,
#              0,      0,      0,      0],
#        [ 31917,     11,  26975,      8,  19659,     24,   3263,     51,
#            172,      0,      4,    550],
#        [    83,     53,     22,     16,     19,     28,      0,      0,
#              0,      1,      0,      0],
#        [ 11808,      3,  11969,      7,  39490,     32,   2627,     27,
#            159,      0,      3,    643],
#        [    55,     34,     41,     16,     78,     47,      1,      0,
#              0,      0,      0,      0],
#        [  6544,      0,   2972,      0,   3960,      1,   9955,     61,
#             43,      0,      0,    186],
#        [  1428,      0,    251,      0,    164,      0,    339,    288,
#             28,      1,      0,     36],
#        [  2606,      3,    786,      0,    683,      0,    417,      4,
#            423,      1,      6,     32],
#        [   201,      0,     11,      0,      3,      0,      4,      1,
#             11,      0,      3,      0],
#        [   325,      0,     61,      0,    105,      0,     16,      1,
#             29,      0,      3,      8],
#        [    60,      0,   1657,      0,    209,      0,    105,     11,
#              7,      0,      0,   1162]])

# %%
# normalized confusion matrix

# %%
normalizeddf1 = pd.DataFrame(metrics.confusion_matrix(y_test1, y_pred1)/ metrics.confusion_matrix(y_test1, y_pred1).astype(np.float).sum(axis=1))
normalizeddf1.columns = ['pred Drive Alone Free','pred Drive Alone Pay','pred HOV2 Free',
                       'pred HOV2 Pay', 'pred HOV3 Free','pred HOV3 Pay','pred Walk','pred BIKE',
                       'pred Walk to Transit', 'pred Park and Ride','pred Kiss and Ride', 'pred School Bus']
normalizeddf1.index = ['pred Drive Alone Free','pred Drive Alone Pay','pred HOV2 Free',
                       'pred HOV2 Pay', 'pred HOV3 Free','pred HOV3 Pay','pred Walk','pred BIKE',
                       'pred Walk to Transit', 'pred Park and Ride','pred Kiss and Ride', 'pred School Bus']

# %%
normalizeddf1
# Out:
#                        pred Drive Alone Free  pred Drive Alone Pay  \
# pred Drive Alone Free               0.858944              0.179435
# pred Drive Alone Pay                0.001752              0.415323
# pred HOV2 Free                      0.221036              0.022177
# pred HOV2 Pay                       0.000575              0.106855
# pred HOV3 Free                      0.081775              0.006048
# pred HOV3 Pay                       0.000381              0.068548
# pred Walk                           0.045320              0.000000
# pred BIKE                           0.009889              0.000000
# pred Walk to Transit                0.018047              0.006048
# pred Park and Ride                  0.001392              0.000000
# pred Kiss and Ride                  0.002251              0.000000
# pred School Bus                     0.000416              0.000000
#
#                        pred HOV2 Free  pred HOV2 Pay  pred HOV3 Free  \
# pred Drive Alone Free        0.125457       0.031532        0.099973
# pred Drive Alone Pay         0.000109       0.072072        0.000060
# pred HOV2 Free               0.326439       0.036036        0.294437
# pred HOV2 Pay                0.000266       0.072072        0.000285
# pred HOV3 Free               0.144844       0.031532        0.591451
# pred HOV3 Pay                0.000496       0.072072        0.001168
# pred Walk                    0.035966       0.000000        0.059310
# pred BIKE                    0.003037       0.000000        0.002456
# pred Walk to Transit         0.009512       0.000000        0.010229
# pred Park and Ride           0.000133       0.000000        0.000045
# pred Kiss and Ride           0.000738       0.000000        0.001573
# pred School Bus              0.020052       0.000000        0.003130
#
#                        pred HOV3 Pay  pred Walk  pred BIKE  \
# pred Drive Alone Free       0.055147   0.119088   0.064694
# pred Drive Alone Pay        0.025735   0.000042   0.000000
# pred HOV2 Free              0.088235   0.137552   0.020118
# pred HOV2 Pay               0.102941   0.000000   0.000000
# pred HOV3 Free              0.117647   0.110741   0.010651
# pred HOV3 Pay               0.172794   0.000042   0.000000
# pred Walk                   0.003676   0.419653   0.024063
# pred BIKE                   0.000000   0.014291   0.113609
# pred Walk to Transit        0.000000   0.017579   0.001578
# pred Park and Ride          0.000000   0.000169   0.000394
# pred Kiss and Ride          0.000000   0.000674   0.000394
# pred School Bus             0.000000   0.004426   0.004339
#
#                        pred Walk to Transit  pred Park and Ride  \
# pred Drive Alone Free              0.037089            0.012821
# pred Drive Alone Pay               0.000000            0.000000
# pred HOV2 Free                     0.034670            0.000000
# pred HOV2 Pay                      0.000000            0.004274
# pred HOV3 Free                     0.032050            0.000000
# pred HOV3 Pay                      0.000000            0.000000
# pred Walk                          0.008668            0.000000
# pred BIKE                          0.005644            0.004274
# pred Walk to Transit               0.085265            0.004274
# pred Park and Ride                 0.002217            0.000000
# pred Kiss and Ride                 0.005846            0.000000
# pred School Bus                    0.001411            0.000000
#
#                        pred Kiss and Ride  pred School Bus
# pred Drive Alone Free            0.009124         0.010589
# pred Drive Alone Pay             0.000000         0.000000
# pred HOV2 Free                   0.007299         0.171286
# pred HOV2 Pay                    0.000000         0.000000
# pred HOV3 Free                   0.005474         0.200249
# pred HOV3 Pay                    0.000000         0.000000
# pred Walk                        0.000000         0.057926
# pred BIKE                        0.000000         0.011211
# pred Walk to Transit             0.010949         0.009966
# pred Park and Ride               0.005474         0.000000
# pred Kiss and Ride               0.005474         0.002491
# pred School Bus                  0.000000         0.361881

# %% [markdown]
# |  | pred Drive Alone Free | pred Drive Alone Pay | pred HOV2 Free | pred HOV2 Pay | pred HOV3 Free | pred HOV3 Pay | pred Walk | pred Bike | pred Walk to Transit | pred Park and Ride | pred Kiss and Ride | pred School Bus |
# | :- | :- | :- | :- | :- | :- | :- | :- | :- | :- | :- | :- | :- |
# | Drive Alone Free | 0.43333333 | 0.01515152 | 0.14848485 | 0 | 0.06060606 | 0.0030303 | 0.05757576 | 0.08181818 | 0.05757576 | 0.1 | 0 | 0.04242424 |
# | Drive Alone Pay | 0.01273885 | 0.70700637 | 0.00318471 | 0.20063694 | 0.00318471 | 0.06687898 | 0 | 0.00318471 | 0 | 0 | 0.00318471 | 0 |
# | HOV2 Free | 0.12941176 | 0.00294118 | 0.25 | 0.01176471 | 0.24705882 | 0.00294118 | 0.08235294 | 0.04411765 | 0.05588235 | 0.03823529 | 0.08529412 | 0.05 |
# | HOV2 Pay | 0.00890208 | 0.25222552| 0.02670623 | 0.40356083 | 0.01186944 | 0.27002967 | 0.00890208 | 0 | 0.00296736 | 0.00890208 | 0.00593472 | 0 |
# | HOV3 Free | 0.05 | 0.00294118 | 0.13823529 | 0.00882353 | 0.47941176 | 0.00882353 | 0.12058824 | 0.02058824 | 0.04705882 | 0.02647059 | 0.05882353 | 0.03823529 |
# | HOV3 Pay | 0 | 0.09763314 | 0.01183432 | 0.28698225 | 0.04142012 | 0.5443787 | 0.00591716 | 0 | 0.00295858 | 0.00295858 | 0.00591716 | 0 |
# | Walk | 0.01807229 | 0 | 0.06927711 | 0.00301205 | 0.0813253 | 0 | 0.63253012 | 0.09638554 | 0.03313253 | 0.01204819 | 0.03313253 | 0.02108434 |
# | Bike | 0.06031746 | 0.0031746 | 0.03809524 | 0 | 0.05079365 | 0 | 0.11746032 | 0.52380952 | 0.04761905 | 0.06666667 | 0.07301587 | 0.01904762 |
# | Walk to Transit | 0.07917889 | 0.00293255 | 0.04398827 | 0.00293255 | 0.05278592 | 0 | 0.07038123 | 0.07038123 | 0.32258065 | 0.17302053 | 0.16129032 | 0.02052786 |
# | Park and Ride | 0.09567901 | 0.02777778 | 0.0154321 | 0.0154321 | 0.01234568 | 0.00925926 | 0.00617284 | 0.03703704 | 0.08333333 | 0.5 | 0.19753086 | 0 |
# | Kiss and Ride | 0.06918239 | 0.00943396 | 0.05345912 | 0.00314465 | 0.05660377 | 0.00628931 | 0.02201258 | 0.02830189 | 0.14465409 | 0.21069182 | 0.36477987 | 0.03144654 |
# | School Bus | 0 | 0 | 0.00302115 | 0 | 0.00906344 | 0 | 0.01812689 | 0 | 0 | 0 | 0.00906344 | 0.96072508 |

# %%
normalizeddf2 = pd.DataFrame(metrics.confusion_matrix(y_test2, y_pred2)/ metrics.confusion_matrix(y_test2, y_pred2).astype(np.float).sum(axis=1))
normalizeddf2.columns = ['pred Drive Alone Free','pred Drive Alone Pay','pred HOV2 Free',
                       'pred HOV2 Pay', 'pred HOV3 Free','pred HOV3 Pay','pred Walk','pred BIKE',
                       'pred Walk to Transit', 'pred Park and Ride','pred Kiss and Ride', 'pred School Bus']
normalizeddf2.index = ['pred Drive Alone Free','pred Drive Alone Pay','pred HOV2 Free',
                       'pred HOV2 Pay', 'pred HOV3 Free','pred HOV3 Pay','pred Walk','pred BIKE',
                       'pred Walk to Transit', 'pred Park and Ride','pred Kiss and Ride', 'pred School Bus']

# %%
normalizeddf2
# Out:
#                        pred Drive Alone Free  pred Drive Alone Pay  \
# pred Drive Alone Free               0.855755              0.162264
# pred Drive Alone Pay                0.002187              0.320755
# pred HOV2 Free                      0.221724              0.018868
# pred HOV2 Pay                       0.000623              0.060377
# pred HOV3 Free                      0.080455              0.000000
# pred HOV3 Pay                       0.000484              0.052830
# pred Walk                           0.044802              0.000000
# pred BIKE                           0.009758              0.000000
# pred Walk to Transit                0.018380              0.000000
# pred Park and Ride                  0.001426              0.000000
# pred Kiss and Ride                  0.002284              0.000000
# pred School Bus                     0.000457              0.000000
#
#                        pred HOV2 Free  pred HOV2 Pay  pred HOV3 Free  \
# pred Drive Alone Free        0.123194       0.035398        0.110417
# pred Drive Alone Pay         0.000072       0.097345        0.000000
# pred HOV2 Free               0.319429       0.044248        0.307848
# pred HOV2 Pay                0.000409       0.079646        0.000452
# pred HOV3 Free               0.139206       0.017699        0.597117
# pred HOV3 Pay                0.000289       0.061947        0.001387
# pred Walk                    0.034645       0.000000        0.060803
# pred BIKE                    0.002837       0.000000        0.002805
# pred Walk to Transit         0.008319       0.000000        0.011431
# pred Park and Ride           0.000120       0.000000        0.000121
# pred Kiss and Ride           0.001082       0.000000        0.001538
# pred School Bus              0.018825       0.000000        0.003921
#
#                        pred HOV3 Pay  pred Walk  pred BIKE  \
# pred Drive Alone Free       0.037879   0.117284   0.057767
# pred Drive Alone Pay        0.060606   0.000000   0.000000
# pred HOV2 Free              0.075758   0.139457   0.018735
# pred HOV2 Pay               0.075758   0.000000   0.000000
# pred HOV3 Free              0.037879   0.111805   0.009368
# pred HOV3 Pay               0.136364   0.000000   0.000000
# pred Walk                   0.007576   0.415889   0.024980
# pred BIKE                   0.000000   0.016009   0.110851
# pred Walk to Transit        0.000000   0.018064   0.000000
# pred Park and Ride          0.000000   0.000342   0.000000
# pred Kiss and Ride          0.000000   0.000770   0.000000
# pred School Bus             0.000000   0.004452   0.008587
#
#                        pred Walk to Transit  pred Park and Ride  \
# pred Drive Alone Free              0.044746            0.032787
# pred Drive Alone Pay               0.000000            0.000000
# pred HOV2 Free                     0.044347            0.008197
# pred HOV2 Pay                      0.000000            0.000000
# pred HOV3 Free                     0.033560            0.000000
# pred HOV3 Pay                      0.000000            0.000000
# pred Walk                          0.006392            0.000000
# pred BIKE                          0.005194            0.000000
# pred Walk to Transit               0.087495            0.008197
# pred Park and Ride                 0.002397            0.000000
# pred Kiss and Ride                 0.005993            0.000000
# pred School Bus                    0.000400            0.000000
#
#                        pred Kiss and Ride  pred School Bus
# pred Drive Alone Free            0.010239         0.013673
# pred Drive Alone Pay             0.000000         0.000000
# pred HOV2 Free                   0.010239         0.181479
# pred HOV2 Pay                    0.000000         0.000622
# pred HOV3 Free                   0.003413         0.214419
# pred HOV3 Pay                    0.000000         0.000000
# pred Walk                        0.000000         0.049720
# pred BIKE                        0.000000         0.014295
# pred Walk to Transit             0.017065         0.008701
# pred Park and Ride               0.000000         0.000000
# pred Kiss and Ride               0.010239         0.003108
# pred School Bus                  0.000000         0.372281

# %%
# check the distribution of prediction result
pd.Series(y_test1).value_counts()/len(y_test1)
# Out:
# 1     0.437567
# 3     0.250406
# 5     0.202327
# 7     0.071885
# 9     0.015033
# 12    0.009730
# 8     0.007682
# 11    0.001661
# 2     0.001503
# 6     0.000824
# 10    0.000709
# 4     0.000673
# dtype: float64

# %%
pd.Series(y_test2).value_counts()/len(y_test2)
# Out:
# 1     0.437891
# 3     0.252079
# 5     0.200945
# 7     0.070794
# 9     0.015170
# 12    0.009752
# 8     0.007764
# 11    0.001776
# 2     0.001606
# 6     0.000800
# 10    0.000739
# 4     0.000685
# dtype: float64

# %%
# metrics.confusion_matrix(y_test, y_pred)[11] / sum(metrics.confusion_matrix(y_test, y_pred)[11])

# %%
# check trips.csv

# %%
trip_mg = pd.merge(utilityvars, trips, on=["activityid"])[['targettripmode', 'modechoice']]
trip_mg
# Out:
#           targettripmode        modechoice
# 0                      1  DRIVE_ALONE_FREE
# 1                      1  DRIVE_ALONE_FREE
# 2                      1  DRIVE_ALONE_FREE
# 3                      1  DRIVE_ALONE_FREE
# 4                      1  DRIVE_ALONE_FREE
# ...                  ...               ...
# 14047024               5      SHARED_3_HOV
# 14047025               3      SHARED_3_HOV
# 14047026               3      SHARED_3_HOV
# 14047027               3      SHARED_3_HOV
# 14047028               5      SHARED_3_HOV
#
# [14047029 rows x 2 columns]

# %%
trip_mg["targettripmode"].replace({1: "DRIVE_ALONE_FREE", 2: "DRIVE_ALONE_PAY", 3: "SHARED_2_HOV", 4: "SHARED_2_PAY", 5: "SHARED_3_HOV", 6: "SHARED_3_PAY", 7: "WALK", 8: "BIKE", 9: "WALK_SET", 10: "PNR_SET", 11: "KNR_SET", 12: "SCH_BUS"}, inplace=True)
trip_mg
# Out:
#             targettripmode        modechoice
# 0         DRIVE_ALONE_FREE  DRIVE_ALONE_FREE
# 1         DRIVE_ALONE_FREE  DRIVE_ALONE_FREE
# 2         DRIVE_ALONE_FREE  DRIVE_ALONE_FREE
# 3         DRIVE_ALONE_FREE  DRIVE_ALONE_FREE
# 4         DRIVE_ALONE_FREE  DRIVE_ALONE_FREE
# ...                    ...               ...
# 14047024      SHARED_3_HOV      SHARED_3_HOV
# 14047025      SHARED_2_HOV      SHARED_3_HOV
# 14047026      SHARED_2_HOV      SHARED_3_HOV
# 14047027      SHARED_2_HOV      SHARED_3_HOV
# 14047028      SHARED_3_HOV      SHARED_3_HOV
#
# [14047029 rows x 2 columns]

# %%
metrics.accuracy_score(trip_mg['targettripmode'], trip_mg['modechoice'])
# Out:
# 0.4792990745587554

# %%
metrics.recall_score(trip_mg['targettripmode'], trip_mg['modechoice'], average = 'macro')
# Out:
# 0.19459360823852725

# %%
metrics.precision_score(trip_mg['targettripmode'], trip_mg['modechoice'], average = 'macro')
# Out:
# 0.19574958766844489

# %%
metrics.confusion_matrix(trip_mg['targettripmode'], trip_mg['modechoice'])
# Out:
# array([[  10170,   42876,       8,      97,     122,    1324,   15767,
#              21,   12382,      34,   22051,    2307],
#        [  21915, 4152601,    5193,    6747,    6837,    3568,  896572,
#            4914,  620743,    5673,  326343,  104119],
#        [      4,   13181,    1514,      36,      38,       0,    1986,
#            1466,     838,    1188,      98,     145],
#        [     29,   10215,      14,     334,     237,     215,    6232,
#              49,    4156,      25,     720,    2089],
#        [     30,    6027,      11,      56,     130,       0,    1737,
#              27,     912,      24,     154,     966],
#        [   1255,    2520,       0,      20,       0,   25297,   53723,
#               4,   46013,      13,    7946,     465],
#        [   7758, 1049745,    1296,    2554,    1824,   76525, 1242758,
#            3813,  877007,    3858,  214324,   41679],
#        [      0,    3390,     395,       9,      26,      81,    2315,
#             851,    1369,     873,     193,      96],
#        [   6381,  512652,     840,    1648,     866,   76531, 1003419,
#            2908, 1013856,    3665,  179717,   28680],
#        [      0,    2423,     253,      11,      13,     179,    3226,
#             894,    2710,    1274,     267,      78],
#        [  21071,  270611,     179,    1384,     639,    9361,  228300,
#             385,  200394,     353,  260649,   10448],
#        [   1032,   90265,      62,     737,    1194,    1042,   51250,
#             118,   34028,     108,   10372,   23294]])

# %%
# age subset
age0 = new_utilityvars[new_utilityvars['age'] == 0]
age1 = new_utilityvars[new_utilityvars['age'] == 1]
age2 = new_utilityvars[new_utilityvars['age'] == 2]
age3 = new_utilityvars[new_utilityvars['age'] == 3]
age4 = new_utilityvars[new_utilityvars['age'] == 4]
age5 = new_utilityvars[new_utilityvars['age'] == 5]
age6 = new_utilityvars[new_utilityvars['age'] == 6]
age7 = new_utilityvars[new_utilityvars['age'] == 7]

# %%
df_array = age0.values
X = df_array[:,0:34]
Y = df_array[:,34]

# %%
seed = 7
test_size = 0.33
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
model = xgb.XGBClassifier()
model.fit(X_train, y_train, eval_set = [(X_train, y_train), (X_test, y_test)], verbose = 0)

# %%
y_pred = [round(value) for value in model.predict(X_test)]
y_test = [round(value) for value in y_test]

# %%
accuracy = metrics.accuracy_score(y_test, y_pred)
accuracy

# %%
sensitivity = metrics.recall_score(y_test, y_pred, average = 'macro')
sensitivity

# %%
df_array = age1.values
X = df_array[:,0:34]
Y = df_array[:,34]

# %%
seed = 7
test_size = 0.33
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
model = xgb.XGBClassifier()
model.fit(X_train, y_train, eval_set = [(X_train, y_train), (X_test, y_test)], verbose = 0)

# %%
y_pred = [round(value) for value in model.predict(X_test)]
y_test = [round(value) for value in y_test]

# %%
accuracy = metrics.accuracy_score(y_test, y_pred)
accuracy

# %% [markdown]
# Age could be an important feature.
